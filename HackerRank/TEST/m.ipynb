# %%
import control as co 
import matplotlib.pyplot as plt 
import numpy as np

# %%
sys = co.tf([1], [1, 2, 1])
sys
# Out:
#       1
# -------------
# s^2 + 2 s + 1

# %%
t, y = co.impulse_response(sys)

# %%
plt.plot(t, y)
plt.grid(True)
plt.show()
